# %% [markdown]
# ## How to import a visualization from a module
# - Step 1: Write a module function that calls `plt.show()` or whatever visualization.
# - Step 2: Import that function from the module and call it!

# %%
from viz import visualize

# %%
visualize()
